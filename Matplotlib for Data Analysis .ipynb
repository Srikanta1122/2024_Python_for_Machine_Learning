# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('apple_quality.csv')
data
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
data.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
data.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
data.isnull().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
data[['Size']].head(3)
# Out:
#        Size
# 0 -3.970049
# 1 -1.195217
# 2 -0.292024

# %%
data.iloc[2]
# Out:
# A_id                   2.0
# Size             -0.292024
# Weight           -1.351282
# Sweetness        -1.738429
# Crunchiness      -0.342616
# Juiciness         2.838636
# Ripeness         -0.038033
# Acidity        2.621636473
# Quality                bad
# Name: 2, dtype: object

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %%
plt.plot(data['Size'],data['Weight'])

# %%
data['Size'].idxmax()
# Out:
# 1381

# %%
data['Size'].idxmin()
# Out:
# 3559

# %%
data.iloc[1381]
# Out:
# A_id                1381.0
# Size              6.406367
# Weight           -2.752347
# Sweetness        -4.164118
# Crunchiness       0.415241
# Juiciness          0.99964
# Ripeness          3.995602
# Acidity        1.724251569
# Quality               good
# Name: 1381, dtype: object

# %%
data.iloc[3559]
# Out:
# A_id                3559.0
# Size             -7.151703
# Weight           -1.370717
# Sweetness         1.673138
# Crunchiness       2.702934
# Juiciness        -0.136146
# Ripeness          4.127709
# Acidity        3.554015134
# Quality                bad
# Name: 3559, dtype: object

# %%
data.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
plt.figure(figsize=(4,4))
plt.plot(data['Size'], data['Juiciness'], color='r',linestyle='--',linewidth=2, marker='o',markersize=5, markerfacecolor='y', 
        markeredgecolor='b', markeredgewidth=3)
plt.xlabel('Size')
plt.ylabel('Juiciness')
a=plt.title('Size vs Juiciness')

# %%
plt.hist(data['Size']) #histrogram work on only one columns
# Out:
# (array([  11.,   68.,  274.,  715., 1048.,  979.,  629.,  218.,   51.,
#            8.]),
#  array([-7.15170306, -5.79589606, -4.44008907, -3.08428207, -1.72847508,
#         -0.37266808,  0.98313892,  2.33894591,  3.69475291,  5.0505599 ,
#          6.4063669 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(data['Size'], data['Juiciness'])

# %%
plt.boxplot(data['Juiciness']) #using boxplot we can easily findout is there any outlier present in our dataset or not
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d8299c3640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d8299c3c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d8299c3370>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d8299d3220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d8299d34f0>],
#  'means': []}

# %%
# subplot

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.plot(data['Size'], data['Juiciness'], color='r',linestyle='--',linewidth=2, marker='o',markersize=5, markerfacecolor='y', 
        markeredgecolor='b', markeredgewidth=3, label='Hii')
plt.subplot(1,3,2) # 1st pos is row, 2nd pos is columns, 3rd pos is position
plt.hist(data['Size']) 
plt.subplot(1,3,3)
plt.scatter(data['Size'], data['Juiciness'])

# %%
fig, ax=plt.subplots(nrows=2, ncols=3, figsize=(8,6))
ax[0][0].plot(data['Size'], data['Juiciness'], color='r',linestyle='--',linewidth=2, marker='o',markersize=5, markerfacecolor='y', 
        markeredgecolor='b', markeredgewidth=3)
ax[0][1].plot(data['Size'], data['Juiciness'])

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Size'], data['Juiciness'], 
        label='Hello')

# %%
df=pd.read_csv('Walmart_sales.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.pie(df['Store'], labels=df['Temperature'], autopct='%1.1f%%')
plt.title('Distribution of Stores by Temperature')
plt.show()
